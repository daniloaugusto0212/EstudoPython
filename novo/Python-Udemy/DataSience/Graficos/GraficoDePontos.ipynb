# %%
import matplotlib.pyplot as plt

# %%
xp = [1, 1, 1.5, 2, 2]

yp = [3, 3.5, 4, 4.5, 5]

xp1 = [3, 3, 3.5, 4, 2]

yp1 = [2, 2.5, 3, 3.5, 2]

x = [1, 2, 3, 4]

y = [2, 3, 4, 5]

plt.plot(x, y)
plt.scatter(xp, yp)
plt.scatter(xp1, yp1)
